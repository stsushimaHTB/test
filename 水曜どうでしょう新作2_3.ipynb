# %% [markdown]
# <a href="https://colab.research.google.com/github/stsushimaHTB/test/blob/master/%E6%B0%B4%E6%9B%9C%E3%81%A9%E3%81%86%E3%81%A7%E3%81%97%E3%82%87%E3%81%86%E6%96%B0%E4%BD%9C2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas部分的につかって少し軽くできないかやってみた

# %%
# %matplotlib inline
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
import datetime
import csv
from tqdm import tqdm_notebook as tqdm
import codecs

# %%
df_log = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Wed8_view_log.txt')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_log.head()
# Out:
#    Unnamed: 0  ...                                      original_data
# 0           0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
# 1           1  ...  |2020-02-19T06:00:05|2020-02-19T06:41:20|50|27...
# 2           2  ...  |2020-02-19T06:00:05|2020-02-19T07:05:16|50|27...
# 3           3  ...  |2020-02-19T06:00:05|2020-02-19T07:36:03|50|27...
# 4           4  ...  |2020-02-19T06:00:06|2020-02-19T06:11:19|50|27...
#
# [5 rows x 11 columns]

# %%
uuid = df_log["unique_id"].unique() #list
print(uuid)
# Out:
# ['c9e5aafe-23bb-4329-8953-5a0189e49bdf'
#  '0d778493-6fa0-4ad8-99bd-474e639c96ac'
#  '4841a7f4-163b-40d1-9dd7-35b9d83451ee' ...
#  'aaddb173-197f-46a9-bdd0-1cfc1a9d4397'
#  'eabba05d-dc7f-4beb-857f-bc0f33df6f0a'
#  'b6466489-cda5-4370-add1-3db135aaffa7']

# %%
Wed_time_list = []

month = 2
day = 19
Wed = "Wed8"
from_dt = dt(2020, month, day, 23, 15 )
to_dt = dt(2020, month, day, 23, 45)

t=to_dt-from_dt
print(t,from_dt,to_dt)
# Out:
# 0:30:00 2020-02-19 23:15:00 2020-02-19 23:45:00

# %%
Wed_time_str = []
for i in range(0,1801):
  Wed_time_list.append(from_dt)
  time_str = from_dt.strftime("%Y-%m-%d %H:%M:%S")
  Wed_time_str.append(time_str)
  print(from_dt)
  from_dt = from_dt + datetime.timedelta(seconds=1)
# Out:
# 2020-02-19 23:15:00
# 2020-02-19 23:15:01
# 2020-02-19 23:15:02
# 2020-02-19 23:15:03
# 2020-02-19 23:15:04
# 2020-02-19 23:15:05
# 2020-02-19 23:15:06
# 2020-02-19 23:15:07
# 2020-02-19 23:15:08
# 2020-02-19 23:15:09
# 2020-02-19 23:15:10
# 2020-02-19 23:15:11
# 2020-02-19 23:15:12
# 2020-02-19 23:15:13
# 2020-02-19 23:15:14
# 2020-02-19 23:15:15
# 2020-02-19 23:15:16
# 2020-02-19 23:15:17
# 2020-02-19 23:15:18
# 2020-02-19 23:15:19
# 2020-02-19 23:15:20
# 2020-02-19 23:15:21
# 2020-02-19 23:15:22
# 2020-02-19 23:15:23
# 2020-02-19 23:15:24
# 2020-02-19 23:15:25
# 2020-02-19 23:15:26
# 2020-02-19 23:15:27
# 2020-02-19 23:15:28
# 2020-02-19 23:15:29
# 2020-02-19 23:15:30
# 2020-02-19 23:15:31
# 2020-02-19 23:15:32
# 2020-02-19 23:15:33
# 2020-02-19 23:15:34
# 2020-02-19 23:15:35
# 2020-02-19 23:15:36
# 2020-02-19 23:15:37
# 2020-02-19 23:15:38
# 2020-02-19 23:15:39
# 2020-02-19 23:15:40
# 2020-02-19 23:15:41
# 2020-02-19 23:15:42
# 2020-02-19 23:15:43
# 2020-02-19 23:15:44
# ...

# %%
Wed_time_str

# %%
len(uuid)
# Out:
# 344102

# %%
#★
for uid in uuid:
  print(uid)
  uid_df =df_log[df_log.unique_id == uid]
  print(uid_df.head())
  df_output_uid = pd.DataFrame(index=[uid],columns=Wed_time_str)
  print(df_output_uid.head())
  break
# Out:
# c9e5aafe-23bb-4329-8953-5a0189e49bdf
#         Unnamed: 0  ...                                      original_data
# 0                0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
# 76502            0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
# 153022           0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
# 229542           0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
# 306062           0  ...  |2020-02-19T06:00:04|2020-02-19T06:31:51|50|27...
#
# [5 rows x 11 columns]

# %%
out_list = [[0 for i in range(1801)] for j in range(len(uuid))]
df = pd.DataFrame(out_list,index=uuid,columns=Wed_time_str)
print(df.head())

# %%
df = pd.DataFrame(index=uuid,columns=Wed_time_str)
print(df.head())
# Out:
#                                      2020-02-19 23:15:00  ... 2020-02-19 23:45:00
# c9e5aafe-23bb-4329-8953-5a0189e49bdf                 NaN  ...                 NaN
# 0d778493-6fa0-4ad8-99bd-474e639c96ac                 NaN  ...                 NaN
# 4841a7f4-163b-40d1-9dd7-35b9d83451ee                 NaN  ...                 NaN
# 7dd5d9bf-f755-4fbc-8fd2-0866296b4274                 NaN  ...                 NaN
# 6fe34d35-43ba-42ea-8ee0-ed6178d7d49a                 NaN  ...                 NaN
#
# [5 rows x 1801 columns]

# %%
df.fillna(0)
print(df.head)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
for line in lines[1:]:
  items = line.rstrip().split(",")
  uuid_index = uuid.index(items[1])
  print("★",uuid_index,items[2],items[3])
  in_str = items[2]
  out_str = items[3]

  in_time = dt.strptime(in_str, '%Y-%m-%d %H:%M:%S')
  
  if in_time < dt(2020, month, day, 23, 15 ) :#大小関係間違える
    print("intime2fromdt",in_time,dt(2020, month, day, 23, 15 ))
    in_time = dt(2020, month, day, 23, 15 )
   
  out_time = dt.strptime(out_str, '%Y-%m-%d %H:%M:%S')
  
  if out_time > dt(2020, month, day, 23, 45 ):
    print("outtime2todt",out_time,dt(2020, month, day, 23, 45 ))
    out_time = dt(2020, month, day, 23, 45 )
   
  #print(in_time,out_time)
 
  if in_time > out_time: #inとoutの時刻逆転まだいたか
    print("<intime")
    continue

  len_time_list = time_list_plus(in_time,out_time)

  for ltl in len_time_list:
    #print(ltl)
    time_index = Wed_time_str.index(ltl)
    """
    if out_list[uuid_index][time_index] == 0:
      out_list[uuid_index][time_index] = 1
    """
    df.at[items[1],ltl] = 1
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# ★ 10452 2020-01-22 23:39:01 2020-01-22 23:40:05
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:40:05 <class 'datetime.datetime'>
# ★ 13309 2020-01-22 23:39:01 2020-01-22 23:44:01
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:44:01 <class 'datetime.datetime'>
# ★ 4752 2020-01-22 23:39:01 2020-01-22 23:40:16
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:40:16 <class 'datetime.datetime'>
# ★ 17072 2020-01-22 23:39:01 2020-01-22 23:39:25
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:39:25 <class 'datetime.datetime'>
# ★ 8243 2020-01-22 23:39:01 2020-01-22 23:44:01
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:44:01 <class 'datetime.datetime'>
# ★ 11817 2020-01-22 23:39:01 2020-01-22 23:44:01
# 2020-01-22 23:39:01 <class 'datetime.datetime'> 2020-01-22 23:44:01 <class 'datetime.datetime'>
# ★ 7216 2020-01-22 23:39:01 2020-01-22 23:40:30
# ...

# %%
df
# Out:
#                                       2020-01-22 23:15:00  ...  2020-01-22 23:45:00
# a337942d-24de-441a-bae7-106bcbcab429                    0  ...                    0
# 4c601a2c-96b3-457a-aa21-325ac56ea82e                    0  ...                    0
# e0983f8c-554c-4220-a18f-bc16b82ed17e                    0  ...                    0
# a1ba43d3-4694-4a02-9041-82bc94617ca2                    0  ...                    0
# c61eaadd-0886-430d-aec7-8ab9101a4710                    0  ...                    0
# ...                                                   ...  ...                  ...
# 13b08803-dae4-4db0-acd1-0a332d1c6f7a                    0  ...                    0
# 9f5ea122-43d3-4b47-a71e-24a8d359e81a                    0  ...                    0
# 3f33bf67-b300-4132-89c9-29331d9836e3                    0  ...                    0
# e04b611a-36da-4f67-8709-14ea76211c98                    0  ...                    0
# ...

# %%
df.to_csv("/content/drive/My Drive/Colab Notebooks/Wed4_df_onehot.csv")
