# %% [markdown]
# <a href="https://colab.research.google.com/github/stsushimaHTB/test/blob/master/%E6%B0%B4%E6%9B%9C%E3%81%A9%E3%81%86%E3%81%A7%E3%81%97%E3%82%87%E3%81%86%E6%96%B0%E4%BD%9C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 合計視聴時間をUUIDごと・各話ごとに算出する

# %%
# %matplotlib inline
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
import csv
from tqdm import tqdm_notebook as tqdm
import codecs

# %%
df4 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200122_Wed4_new.csv')
df5 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200129_Wed5_new.csv')
df6 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200205_Wed6_new.csv')
df7 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200212_Wed7_new.csv')
df8 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200219_Wed8_new.csv')
df9 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200226_Wed9_new.csv')
df10 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200304_Wed10_new.csv')
df11 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/onehot_howisWednesday_20200311_Wed11_new.csv')

# %%
output_file4 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed4.csv"
output_file5 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed5.csv"
output_file6 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed6.csv"
output_file7 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed7.csv"
output_file8 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed8.csv"
output_file9 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed9.csv"
output_file10 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed10.csv"
output_file11 = "/content/drive/My Drive/Colab Notebooks/howlong_Wed11.csv"

# %%
df8.head()
# Out:
#                              Unnamed: 0  ...  2020-02-19 23:45:00
# 0  ebe47187-996a-48f0-92cb-33f25cc40018  ...                    0
# 1  cc52e7ee-6db8-4be0-9f87-7441d8ece0b6  ...                    0
# 2  c76fd131-0da3-4664-a302-a14d5ed2c171  ...                    0
# 3  1ee5f40f-79cb-4d43-9e26-21d4f74c135a  ...                    0
# 4  d0c9d5c7-d17c-4858-8fc6-933edf8a64d9  ...                    0
#
# [5 rows x 1802 columns]

# %%
id_ser4 = df4["Unnamed: 0"].unique()
id_ser5 = df5["Unnamed: 0"].unique()
id_ser6 = df6["Unnamed: 0"].unique()
id_ser7 = df7["Unnamed: 0"].unique()
id_ser8 = df8["Unnamed: 0"].unique()
id_ser9 = df9["Unnamed: 0"].unique()
id_ser10 = df10["Unnamed: 0"].unique()
id_ser11 = df11["Unnamed: 0"].unique()

print(id_ser4)
# Out:
# ['950331c8-0b02-4f05-a40d-9dfaa7897f9d'
#  '62bd5c9b-7863-423f-815a-cd352b61bedb'
#  '6af6e4db-5362-4955-8c99-80bd62cf88d4' ...
#  '4c74f66b-c783-45c9-850c-79fdcfc89d2b'
#  'c927cf5f-be26-421d-8a58-7d968912f5e8'
#  'b6725f3f-f62b-443f-af44-c030d63e5126']

# %%
print(len(id_ser4),len(id_ser5),len(id_ser6),len(id_ser7),len(id_ser8),len(id_ser9),len(id_ser10),len(id_ser11))
# Out:
# 18784 37842 36317 31789 20897 35073 35016 33747

# %%
df_temp4 = (df4 == 1) #1のところだけTrueにしたシリーズ
df_temp5 = (df5 == 1)
df_temp6 = (df6 == 1)
df_temp7 = (df7 == 1)
df_temp8 = (df8 == 1)
df_temp9 = (df9 == 1)
df_temp10 = (df10 == 1)
df_temp11 = (df11 == 1)

print(df_temp4)
# Out:
#        Unnamed: 0  ...  2020-01-22 23:45:00
# 0           False  ...                False
# 1           False  ...                False
# 2           False  ...                False
# 3           False  ...                False
# 4           False  ...                False
# ...           ...  ...                  ...
# 18779       False  ...                False
# 18780       False  ...                False
# 18781       False  ...                False
# 18782       False  ...                False
# 18783       False  ...                False
#
# [18784 rows x 1802 columns]

# %%
df_count4 = df_temp4.sum(axis=1) #Series　行ごとにTrueの数を数える
df_count5 = df_temp5.sum(axis=1)
df_count6 = df_temp6.sum(axis=1)
df_count7 = df_temp7.sum(axis=1)
df_count8 = df_temp8.sum(axis=1)
df_count9 = df_temp9.sum(axis=1)
df_count10 = df_temp10.sum(axis=1)
df_count11 = df_temp11.sum(axis=1)

print(df_count4)
# Out:
# 0        1707
# 1        1711
# 2        1731
# 3        1733
# 4        1734
#          ...
# 18779       1
# 18780       1
# 18781       1
# 18782       1
# 18783       1
# Length: 18784, dtype: int64

# %%
uniq_count4 = df_count4.value_counts() #ユニークな要素の値とその出現回数をpandas.Seriesで返す
uniq_count5 = df_count5.value_counts()
uniq_count6 = df_count6.value_counts()
uniq_count7 = df_count7.value_counts()
uniq_count8 = df_count8.value_counts()
uniq_count9 = df_count9.value_counts()
uniq_count10 = df_count10.value_counts()
uniq_count11 = df_count11.value_counts()

print(uniq_count4)
# Out:
# 1740    3153
# 1       1149
# 1739    1021
# 2        573
# 3        532
#         ...
# 552        1
# 577        1
# 1276       1
# 1018       1
# 1486       1
# Length: 1698, dtype: int64

# %%
count_dic4 = {} #秒
for i in range(1,1801):
  try:
    count_dic4[i] = uniq_count4[i]
  except:
    count_dic4[i] = 0

print(count_dic4)

count_dic5 = {} #秒
for i in range(1,1801):
  try:
    count_dic5[i] = uniq_count5[i]
  except:
    count_dic5[i] = 0

count_dic6 = {} #秒
for i in range(1,1801):
  try:
    count_dic6[i] = uniq_count6[i]
  except:
    count_dic6[i] = 0

count_dic7 = {} #秒
for i in range(1,1801):
  try:
    count_dic7[i] = uniq_count7[i]
  except:
    count_dic7[i] = 0

count_dic8 = {} #秒
for i in range(1,1801):
  try:
    count_dic8[i] = uniq_count8[i]
  except:
    count_dic8[i] = 0

count_dic9 = {} #秒
for i in range(1,1801):
  try:
    count_dic9[i] = uniq_count9[i]
  except:
    count_dic9[i] = 0

count_dic10 = {} #秒
for i in range(1,1801):
  try:
    count_dic10[i] = uniq_count10[i]
  except:
    count_dic10[i] = 0

count_dic11 = {} #秒
for i in range(1,1801):
  try:
    count_dic11[i] = uniq_count11[i]
  except:
    count_dic11[i] = 0
# Out:
# {1: 1149, 2: 573, 3: 532, 4: 377, 5: 305, 6: 217, 7: 177, 8: 139, 9: 144, 10: 121, 11: 96, 12: 97, 13: 94, 14: 73, 15: 69, 16: 84, 17: 65, 18: 59, 19: 51, 20: 52, 21: 52, 22: 52, 23: 44, 24: 43, 25: 46, 26: 37, 27: 50, 28: 33, 29: 35, 30: 35, 31: 38, 32: 36, 33: 22, 34: 22, 35: 20, 36: 18, 37: 29, 38: 22, 39: 25, 40: 19, 41: 19, 42: 27, 43: 27, 44: 22, 45: 19, 46: 27, 47: 22, 48: 12, 49: 22, 50: 17, 51: 25, 52: 18, 53: 26, 54: 41, 55: 22, 56: 25, 57: 27, 58: 23, 59: 30, 60: 29, 61: 35, 62: 18, 63: 15, 64: 16, 65: 16, 66: 13, 67: 18, 68: 18, 69: 14, 70: 7, 71: 16, 72: 12, 73: 10, 74: 10, 75: 17, 76: 16, 77: 9, 78: 13, 79: 18, 80: 12, 81: 16, 82: 16, 83: 11, 84: 11, 85: 10, 86: 7, 87: 17, 88: 9, 89: 5, 90: 11, 91: 16, 92: 10, 93: 15, 94: 15, 95: 9, 96: 10, 97: 16, 98: 18, 99: 10, 100: 14, 101: 15, 102: 10, 103: 15, 104: 16, 105: 17, 106: 10, 107: 13, 108: 10, 109: 21, 110: 10, 111: 13, 112: 11, 113: 11, 114: 12, 115: 12, 116: 13, 117: 9, 118: 17, 119: 10, 120: 14, 121: 14, 122: 9, 123:
# ...

# %%
min_count_dic4 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic4[i*60+j]
  min_count_dic4[i] = counter

print(min_count_dic4)

min_count_dic5 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic5[i*60+j]
  min_count_dic5[i] = counter

min_count_dic6 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic6[i*60+j]
  min_count_dic6[i] = counter

min_count_dic7 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic7[i*60+j]
  min_count_dic7[i] = counter

min_count_dic8 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic8[i*60+j]
  min_count_dic8[i] = counter

min_count_dic9 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic9[i*60+j]
  min_count_dic9[i] = counter

min_count_dic10 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic10[i*60+j]
  min_count_dic10[i] = counter

min_count_dic11 = {} #分ごとにまとめる
for i in range(0,30):
  counter = 0
  for j in range(1,60):
    counter += count_dic11[i*60+j]
  min_count_dic11[i] = counter
# Out:
# {0: 5603, 1: 794, 2: 683, 3: 573, 4: 404, 5: 455, 6: 488, 7: 304, 8: 341, 9: 270, 10: 279, 11: 287, 12: 311, 13: 232, 14: 242, 15: 220, 16: 163, 17: 207, 18: 170, 19: 146, 20: 165, 21: 149, 22: 173, 23: 223, 24: 189, 25: 189, 26: 222, 27: 203, 28: 1661, 29: 151}

# %%
f = open(output_file4, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic4.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file5, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic5.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file6, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic6.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file7, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic7.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file8, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic8.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file9, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic9.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file10, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic10.items()):
  f.write(f'{key},{value}\n')
f.close()

f = open(output_file11, 'w') # 書き込みモードで開く
for key,value in sorted(min_count_dic11.items()):
  f.write(f'{key},{value}\n')
f.close()
